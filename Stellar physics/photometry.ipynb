# %%
import numpy as np
from astropy.io import fits
import glob

# %%
dy_peg = glob.glob('/Users/liuweijie/Desktop/DYPEG/*.fit')
dy_peg_1 = dy_peg[0]
dy_peg_1
# Out:
# '/Users/liuweijie/Desktop/DYPEG/DYpeg-1-0001G.fit'

# %%
hdu = fits.open(dy_peg_1)

# %%
hdu.info
# Out:
# <bound method HDUList.info of [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f7b48c39e20>]>

# %%
hdu.close()

# %%
hdu[0].header
# Out:
# SIMPLE  =                    T
# BITPIX  =                   16 /8 unsigned int, 16 & 32 int, -32 & -64 real
# NAXIS   =                    2 /number of axes
# NAXIS1  =                 1676 /fastest changing axis
# NAXIS2  =                 1266 /next to fastest changing axis
# BSCALE  =   1.0000000000000000 /physical = BZERO + BSCALE*array_value
# BZERO   =   32768.000000000000 /physical = BZERO + BSCALE*array_value
# DATE-OBS= '2023-07-30T18:43:11' /YYYY-MM-DDThh:mm:ss observation start, UT
# EXPTIME =   30.000000000000000 /Exposure time in seconds
# EXPOSURE=   30.000000000000000 /Exposure time in seconds
# SET-TEMP=   5.0000000000000000 /CCD temperature setpoint in C
# CCD-TEMP=   4.8897595633312960 /CCD temperature at start of exposure in C
# XPIXSZ  =   10.800000000000001 /Pixel Width in microns (after binning)
# YPIXSZ  =   10.800000000000001 /Pixel Height in microns (after binning)
# XBINNING=                    2 /Binning factor in width
# ...

# %%
hdu.info
# Out:
# <bound method HDUList.info of [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f7b48c39e20>]>

# %%
hdu.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 hdu.data
#
# AttributeError: 'HDUList' object has no attribute 'data'

# %%
from photutils.aperture import CircularAperature

positions = [(30.0, 30.0), (40.0, 40.0)]
aperture = CircularAperature(positions, r=3.0)
# Out:
#   Cell In[2], line 1
#     from photutils.aperture import CircularAperaturepositions = [(30.0, 30.0), (40.0, 40.0)]
#                                                               ^
# SyntaxError: invalid syntax
